# %% [markdown]
# # Luggage detection experiments
# Use this notebook for threshold sweeps and visual inspection. Canonical training/evaluation remains in `src/` for reproducibility.

# %%
from pathlib import Path
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
ROOT
